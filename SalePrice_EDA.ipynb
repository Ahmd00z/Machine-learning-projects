# %% [markdown]
# # **Importing libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # *Data loading*

# %%
data = pd.read_csv('train_3.csv')

# %% [markdown]
# # *Data Inspection*

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data.describe().T
# Out:
#                 count           mean           std      min        25%  \
# Id             1460.0     730.500000    421.610009      1.0     365.75
# MSSubClass     1460.0      56.897260     42.300571     20.0      20.00
# LotFrontage    1201.0      70.049958     24.284752     21.0      59.00
# LotArea        1460.0   10516.828082   9981.264932   1300.0    7553.50
# OverallQual    1460.0       6.099315      1.382997      1.0       5.00
# OverallCond    1460.0       5.575342      1.112799      1.0       5.00
# YearBuilt      1460.0    1971.267808     30.202904   1872.0    1954.00
# YearRemodAdd   1460.0    1984.865753     20.645407   1950.0    1967.00
# MasVnrArea     1452.0     103.685262    181.066207      0.0       0.00
# BsmtFinSF1     1460.0     443.639726    456.098091      0.0       0.00
# BsmtFinSF2     1460.0      46.549315    161.319273      0.0       0.00
# BsmtUnfSF      1460.0     567.240411    441.866955      0.0     223.00
# ...

# %% [markdown]
# # **Data** **Cleaning**

# %%
print(data.isnull().sum())
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %% [markdown]
# handling missing values

# %%
columns_to_delete = ['LotFrontage', 'MasVnrType', 'Alley' , 'FireplaceQu' , 'PoolQC' , 'Fence' ,'MiscFeature']
data = data.drop(columns=columns_to_delete)

# %%
columns_to_fill_mode = ['BsmtQual' , 'BsmtCond' , 'BsmtExposure', 'BsmtFinType1' , 'Electrical' , 'GarageType' , 'GarageYrBlt' , 'GarageFinish' ,'GarageQual' ,'GarageCond']
columns_to_fill_mean = ['MasVnrArea', 'GarageYrBlt']
for column in columns_to_fill_mean:
    data[column].fillna(data[column].mean(), inplace=True)

for column in columns_to_fill_mode:
    mode_value = data[column].mode()[0]  # Get the mode (first value if multiple modes exist)
    data[column].fillna(mode_value, inplace=True)
# Out:
# /tmp/ipython-input-2221927554.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data[column].fillna(data[column].mean(), inplace=True)
# /tmp/ipython-input-2221927554.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
print(data.isnull().sum())
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
#                 ..
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# Length: 74, dtype: int64

# %% [markdown]
# # **EDA**

# %%
numerical_data = data.select_dtypes(include=['float64'])

corr = numerical_data.corr()

plt.figure(figsize=(10, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of my Dataset')
plt.show()

# %%
numerical_data = data.select_dtypes(include=['int64'])

corr = numerical_data.corr()

# Plot the heatmap
plt.figure(figsize=(32, 16))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of my Dataset')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='LotShape', hue='SaleCondition', data=data)
plt.title('Survival Count by Gender')
plt.xlabel('shape')
plt.ylabel('condition')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.histplot(data['SalePrice'], bins=30, kde=True)
plt.title('SalePrice Distribution')
plt.xlabel('price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.barplot(x='SaleType', y='SalePrice', data=data)
plt.title('Sale price by sale type')
plt.xlabel('type')
plt.ylabel('price')
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x='Street', y='SalePrice', data=data)
plt.title('price Distribution by street')
plt.xlabel('Street')
plt.ylabel('price')
plt.show()

# %%
sns.scatterplot(x='LotArea', y='SalePrice', data=data)
plt.title("LotArea vs. SalePrice")
plt.xlabel("LotArea")
plt.ylabel("SalePrice")
plt.show()

# %%
sns.barplot(x='LotShape', y='SalePrice', data=data, estimator=sum, ci=None)
plt.title("Total price by shape")
plt.xlabel("Shape")
plt.ylabel("Price")
plt.show()
# Out:
# /tmp/ipython-input-1944711485.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='LotShape', y='SalePrice', data=data, estimator=sum, ci=None)

# %%
sns.violinplot(x='Street', y='SalePrice', data=data)
plt.title("Total SalePrice Distribution by Street (Violin Plot)")
plt.xlabel("Street")
plt.ylabel("SalePrice")
plt.show()

# %% [markdown]
# ### **MODEL**

# %%
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import  OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %%
X = data.drop('SalePrice', axis=1)
y = data['SalePrice']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
categorical_cols = X_train.select_dtypes(include=["object"]).columns
numeric_cols = X_train.select_dtypes(include=["int64", "float64"]).columns

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols)
    ]
)

# %%
X_train_processed = preprocessor.fit_transform(X_train)
X_test_processed = preprocessor.transform(X_test)

print("Train shape after preprocessing:", X_train_processed.shape)
print("Test shape after preprocessing:", X_test_processed.shape)
# Out:
# Train shape after preprocessing: (1095, 263)
# Test shape after preprocessing: (365, 263)

# %%
linear_model = LinearRegression()
linear_model.fit(X_train_processed, y_train)

y_pred_linear = linear_model.predict(X_test_processed)

r2_linear = r2_score(y_test, y_pred_linear)
print("R² score (Linear Regression):", r2_linear)
# Out:
# R² score (Linear Regression): 0.8856818285102188

# %%
# 1. Polynomial Linear Regression
poly_pipeline = Pipeline([
    ("preprocess", preprocessor),
    ("poly", PolynomialFeatures(degree=5, include_bias=False)),
    ("model", LinearRegression())
])

# 2. KNN
knn_pipeline = Pipeline([
    ("preprocess", preprocessor),
    ("model", KNeighborsRegressor())
])

# 3. XGBoost
xgb_pipeline = Pipeline([
    ("preprocess", preprocessor),
    ("model", XGBRegressor(objective="reg:squarederror", random_state=42))
])

# =====================
# Define Parameter Grids
# =====================
param_grid = {
    "poly": {
        "poly__degree": [1, 2]
    },
    "knn": {
        "model__n_neighbors": [3, 5, 7],
        "model__weights": ["uniform", "distance"]
    },
    "xgb": {
        "model__n_estimators": [100, 200],
        "model__max_depth": [3, 5],
        "model__learning_rate": [0.05, 0.1]
    }
}

# =====================
# Run GridSearchCV for each model
# =====================
models = {
    "Polynomial Regression": (poly_pipeline, param_grid["poly"]),
    "KNN Regressor": (knn_pipeline, param_grid["knn"]),
    "XGBoost Regressor": (xgb_pipeline, param_grid["xgb"])
}

best_models = {}
for name, (pipe, params) in models.items():
    grid = GridSearchCV(pipe, params, cv=3, scoring="r2", n_jobs=-1)
    grid.fit(X_train, y_train)
    best_models[name] = grid
    print(f"\n{name}")
    print("Best Params:", grid.best_params_)
    print("Best CV R²:", grid.best_score_)

# =====================
# Evaluate Best Models on Test Set
# =====================
for name, grid in best_models.items():
    y_pred = grid.predict(X_test)
    r2 = r2_score(y_test, y_pred)
    print(f"{name} - Test R²: {r2:.4f}")
# Out:
# Polynomial Regression
# Best Params: {'poly__degree': 2}
# Best CV R²: 0.7430427977433757
#
# KNN Regressor
# Best Params: {'model__n_neighbors': 7, 'model__weights': 'distance'}
# Best CV R²: 0.7594420309017672
#
# XGBoost Regressor
# Best Params: {'model__learning_rate': 0.1, 'model__max_depth': 3, 'model__n_estimators': 200}
# Best CV R²: 0.877371629079183
# Polynomial Regression - Test R²: 0.7279
# KNN Regressor - Test R²: 0.8234
# XGBoost Regressor - Test R²: 0.9120

# %% [markdown]
# # TEST **CSV**

# %%
data_test = pd.read_csv('test.csv')

# %%
columns_to_delete = ['LotFrontage', 'MasVnrType', 'Alley' , 'FireplaceQu' , 'PoolQC' , 'Fence' ,'MiscFeature']
data_test = data_test.drop(columns=columns_to_delete)

# %%
columns_to_fill_mode = ['BsmtQual' , 'MSZoning' ,'SaleType' , 'BsmtCond' , 'BsmtExposure', 'BsmtFinType1' , 'Electrical' , 'GarageType' , 'GarageYrBlt' , 'GarageFinish' ,'GarageQual' ,'GarageCond']
columns_to_fill_mean = ['MasVnrArea', 'GarageYrBlt']
for column in columns_to_fill_mean:
    data_test[column].fillna(data_test[column].mean(), inplace=True)

for column in columns_to_fill_mode:
    mode_value = data_test[column].mode()[0]  # Get the mode (first value if multiple modes exist)
    data_test[column].fillna(mode_value, inplace=True)
# Out:
# /tmp/ipython-input-3436910685.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_test[column].fillna(data_test[column].mean(), inplace=True)
# /tmp/ipython-input-3436910685.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
print(data_test.isnull().sum())
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 73, dtype: int64

# %%
numerical_data = data_test.select_dtypes(include=['int64' , 'float64'])

corr = numerical_data.corr()

# Plot the heatmap
plt.figure(figsize=(36, 18))
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix of my Dataset')
plt.show()

# %%
Xt =data_test.copy()

# %%
categorical_cols = Xt.select_dtypes(include=["object"]).columns
numeric_cols = Xt.select_dtypes(include=["int64", "float64"]).columns

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), categorical_cols)
    ]
)

# %%
print(Xt.isnull().sum())
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
#                 ..
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# Length: 73, dtype: int64

# %%
Xt.describe()
# Out:
#                 Id   MSSubClass       LotArea  OverallQual  OverallCond  \
# count  1459.000000  1459.000000   1459.000000  1459.000000  1459.000000
# mean   2190.000000    57.378341   9819.161069     6.078821     5.553804
# std     421.321334    42.746880   4955.517327     1.436812     1.113740
# min    1461.000000    20.000000   1470.000000     1.000000     1.000000
# 25%    1825.500000    20.000000   7391.000000     5.000000     5.000000
# 50%    2190.000000    50.000000   9399.000000     6.000000     5.000000
# 75%    2554.500000    70.000000  11517.500000     7.000000     6.000000
# max    2919.000000   190.000000  56600.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  1459.000000   1459.000000  1459.000000  1459.000000  1459.000000  ...
# mean   1971.357779   1983.662783   100.709141   439.142906    52.583276  ...
# std      30.390071     21.130467   176.709824   455.117812   176.698671  ...
# ...

# %%
print(f"Missing values: {Xt.isna().sum().sum()}")
print(f"Null values: {Xt.isnull().sum().sum()}")
print(f"Duplicate records: {Xt.duplicated().sum()}")
# Out:
# Missing values: 0
# Null values: 0
# Duplicate records: 0

# %%
Xt.isnull().sum().sort_values(ascending=False).head(20)
# Out:
# Id              0
# MSSubClass      0
# MSZoning        0
# LotArea         0
# Street          0
# LotShape        0
# LandContour     0
# Utilities       0
# LotConfig       0
# LandSlope       0
# Neighborhood    0
# Condition1      0
# Condition2      0
# BldgType        0
# HouseStyle      0
# OverallQual     0
# OverallCond     0
# YearBuilt       0
# YearRemodAdd    0
# RoofStyle       0
# dtype: int64

# %%
Xt[numeric_cols] = Xt[numeric_cols].fillna(Xt[numeric_cols].median())
Xt[categorical_cols] = Xt[categorical_cols].fillna(Xt[categorical_cols].mode().iloc[0])

# %%
print(f"Missing values: {Xt.isna().sum().sum()}")
print(f"Null values: {Xt.isnull().sum().sum()}")
print(f"Duplicate records: {Xt.duplicated().sum()}")
# Out:
# Missing values: 0
# Null values: 0
# Duplicate records: 0

# %%
Xt_processed = preprocessor.fit_transform(Xt)

# %%
for name, grid in best_models.items():
    y_predt = grid.predict(Xt)
